# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
path = r'C:\Users\firoj\OneDrive\Desktop\thesis_test\Thesis_test_01\Final_data'
os.chdir(path)

# %%
df = pd.read_csv('main_data.csv')
df.head()
# Out:
#       ais_timestamp  vessel_mmsi  vessel_length       lon       lat  distance  \
# 0  01.05.2023 07:08  210090000.0           88.0  8.545379  53.56142      0.00
# 1  01.05.2023 07:11  210090000.0           88.0  8.554007  53.55247      1.15
# 2  01.05.2023 07:14  210090000.0           88.0  8.562378  53.54377      1.11
# 3  01.05.2023 07:17  210090000.0           88.0  8.567384  53.53481      1.05
# 4  01.05.2023 07:20  210090000.0           88.0  8.562150  53.52593      1.05
#
#    speed  destination_lat  destination_lon  remaining_distance  lock_status  \
# 0  110.0         53.49468            8.504            7.909105          1.0
# 1  112.0         53.49468            8.504            7.226372          1.0
# 2  111.0         53.49468            8.504            6.685145          1.0
# 3  110.0         53.49468            8.504            6.121669          1.0
# 4  110.0         53.49468            8.504            5.182657          1.0
#
# ...

# %%
df.shape
# Out:
# (81266, 19)

# %%
df['vessel_mmsi'].value_counts()
# Out:
# vessel_mmsi
# 636022775.0    2488
# 305094000.0    1907
# 314463000.0    1769
# 211467160.0    1688
# 210529000.0    1586
#                ...
# 246140000.0      10
# 244670434.0      10
# 244710719.0       9
# 261185310.0       5
# 211496830.0       3
# Name: count, Length: 376, dtype: int64

# %%
final_data = df[df['vessel_mmsi'] == 636022775.0]

# %%
final_data.head()
# Out:
#          ais_timestamp  vessel_mmsi  vessel_length       lon       lat  \
# 9795  03.06.2023 15:29  636022775.0           89.0  8.548047  53.56437
# 9798  03.06.2023 15:32  636022775.0           89.0  8.548866  53.56409
# 9800  03.06.2023 15:35  636022775.0           89.0  8.548948  53.56515
# 9803  03.06.2023 15:38  636022775.0           89.0  8.548944  53.56576
# 9805  03.06.2023 15:39  636022775.0           89.0  8.549474  53.56756
#
#       distance  speed  destination_lat  destination_lon  remaining_distance  \
# 9795      0.00   18.0          53.4914         8.502147            8.662548
# 9798      0.06    6.0          53.4914         8.502147            8.652568
# 9800      0.12   10.0          53.4914         8.502147            8.764671
# 9803      0.07   17.0          53.4914         8.502147            8.828067
# 9805      0.20   21.0          53.4914         8.502147            9.027858
#
#       lock_status  water_level_cm  max_cm  sig_cm  turb_cm     tp      sine  \
# ...

# %%
final_data.shape
# Out:
# (2488, 19)

# %%
final_data.columns
# Out:
# Index(['ais_timestamp', 'vessel_mmsi', 'vessel_length', 'lon', 'lat',
#        'distance', 'speed', 'destination_lat', 'destination_lon',
#        'remaining_distance', 'lock_status', 'water_level_cm', 'max_cm',
#        'sig_cm', 'turb_cm', 'tp', 'sine', 'cosine', 'target'],
#       dtype='object')

# %%
# Convert the date-time column to a datetime object with the specified format
final_data['ais_timestamp'] = pd.to_datetime(final_data['ais_timestamp'], format='%d.%m.%Y %H:%M')

# Convert the datetime object to a numeric representation, like Unix timestamp
final_data['ais_timestamp'] = final_data['ais_timestamp'].view('int64')
# Out:
# C:\Users\firoj\AppData\Local\Temp\ipykernel_24056\417785984.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_data['ais_timestamp'] = pd.to_datetime(final_data['ais_timestamp'], format='%d.%m.%Y %H:%M')
# C:\Users\firoj\AppData\Local\Temp\ipykernel_24056\417785984.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_data['ais_timestamp'] = final_data['ais_timestamp'].view('int64')

# %%
final_data
# Out:
#              ais_timestamp  vessel_mmsi  vessel_length       lon       lat  \
# 9795   1685806140000000000  636022775.0           89.0  8.548047  53.56437
# 9798   1685806320000000000  636022775.0           89.0  8.548866  53.56409
# 9800   1685806500000000000  636022775.0           89.0  8.548948  53.56515
# 9803   1685806680000000000  636022775.0           89.0  8.548944  53.56576
# 9805   1685806740000000000  636022775.0           89.0  8.549474  53.56756
# ...                    ...          ...            ...       ...       ...
# 33314  1686672840000000000  636022775.0           89.0  8.490802  53.45075
# 33324  1686673080000000000  636022775.0           89.0  8.490929  53.45270
# 33328  1686673200000000000  636022775.0           89.0  8.490956  53.45305
# 33337  1686673440000000000  636022775.0           89.0  8.491147  53.45433
# 33345  1686673620000000000  636022775.0           89.0  8.491596  53.45877
#
# ...

# %% [markdown]
# ### Descriptive Statistics

# %%
final_data.describe()
# Out:
#        ais_timestamp  vessel_mmsi  vessel_length          lon          lat  \
# count   2.488000e+03       2488.0         2488.0  2488.000000  2488.000000
# mean    1.686041e+18  636022775.0           89.0     8.551317    53.552798
# std     1.619448e+14          0.0            0.0     0.015613     0.073341
# min     1.685806e+18  636022775.0           89.0     8.480795    53.121030
# 25%     1.685918e+18  636022775.0           89.0     8.552455    53.569870
# 50%     1.686030e+18  636022775.0           89.0     8.552470    53.569880
# 75%     1.686141e+18  636022775.0           89.0     8.552482    53.569890
# max     1.686674e+18  636022775.0           89.0     8.688725    53.573960
#
#           distance        speed  destination_lat  destination_lon  \
# count  2488.000000  2488.000000      2488.000000      2488.000000
# mean      0.040422     4.637460        53.479135         8.505479
# std       0.156782    17.105728         0.058027         0.026045
# ...

# %% [markdown]
# ### Missing Values

# %%
final_data.isnull().sum()
# Out:
# ais_timestamp         0
# vessel_mmsi           0
# vessel_length         0
# lon                   0
# lat                   0
# distance              0
# speed                 0
# destination_lat       0
# destination_lon       0
# remaining_distance    0
# lock_status           0
# water_level_cm        0
# max_cm                0
# sig_cm                0
# turb_cm               0
# tp                    0
# sine                  0
# cosine                0
# target                0
# dtype: int64

# %% [markdown]
# ### Correlation Analysis

# %%
# Calculate correlation matrix
correlation_matrix = final_data.corr()
correlation_matrix
# Out:
#                     ais_timestamp  vessel_mmsi  vessel_length       lon  \
# ais_timestamp            1.000000          NaN            NaN -0.170711
# vessel_mmsi                   NaN          NaN            NaN       NaN
# vessel_length                 NaN          NaN            NaN       NaN
# lon                     -0.170711          NaN            NaN  1.000000
# lat                     -0.570477          NaN            NaN  0.002833
# distance                 0.576240          NaN            NaN -0.286410
# speed                    0.613260          NaN            NaN -0.310329
# destination_lat         -0.416533          NaN            NaN  0.077697
# destination_lon          0.124475          NaN            NaN  0.039828
# remaining_distance       0.072249          NaN            NaN  0.054526
# lock_status                   NaN          NaN            NaN       NaN
# water_level_cm          -0.052415          NaN            NaN  0.073389
# ...

# %%
# Create a heatmap
plt.figure(figsize=(8, 6))  # You can adjust the size of the figure
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=.5)
plt.title('Correlation Matrix Heatmap')
plt.show()

# %% [markdown]
# ### Data Distribution

# %%
# Set up the matplotlib figure
plt.figure(figsize=(15, 5))

# Distribution plot for 'speed'
plt.subplot(1, 3, 1)
sns.histplot(final_data['speed'], kde=True)
plt.title('Speed Distribution')

# Distribution plot for 'vessel length'
plt.subplot(1, 3, 2)
sns.histplot(final_data['vessel_length'], kde=True)
plt.title('Vessel Length Distribution')

# Distribution plot for 'travel time duration'
plt.subplot(1, 3, 3)
sns.histplot(final_data['target'], kde=True)
plt.title('Travel Time Duration Distribution')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Relationship Between Features

# %%
# Set up the matplotlib figure
plt.figure(figsize=(12, 6))

# Scatter plot for Speed vs. Travel Time Duration
plt.subplot(1, 2, 1)
sns.scatterplot(x='speed', y='target', data=final_data)
plt.title('Speed vs. Travel Time Duration')

# Scatter plot for Vessel Length vs. Speed
plt.subplot(1, 2, 2)
sns.scatterplot(x='vessel_length', y='speed', data=final_data)
plt.title('Vessel Length vs. Speed')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Univariate Analysis

# %%
sns.boxplot(x=final_data['speed'])
plt.title('Boxplot of Speed')
plt.show()

# %%
sns.boxplot(x=final_data['vessel_length'])
plt.title('Boxplot of Vessel Length')
plt.show()

# %%
sns.boxplot(x=final_data['target'])
plt.title('Boxplot of Travel Time Duration')
plt.show()

# %%
# Box Plot
plt.figure(figsize=(8, 6))
plt.boxplot(final_data['max_cm'], vert=False)
plt.title('Box Plot of max_cm Values')
plt.xlabel('max_cm')
plt.show()

# %%
# Box Plot
plt.figure(figsize=(8, 6))
plt.boxplot(final_data['sig_cm'], vert=False)
plt.title('Box Plot of sig_cm Values')
plt.xlabel('max_cm')
plt.show()

# %%
# Box Plot
plt.figure(figsize=(8, 6))
plt.boxplot(final_data['turb_cm'], vert=False)
plt.title('Box Plot of turb_cm Values')
plt.xlabel('max_cm')
plt.show()

# %%
# Box Plot
plt.figure(figsize=(8, 6))
plt.boxplot(final_data['tp'], vert=False)
plt.title('Box Plot of tp Values')
plt.xlabel('max_cm')
plt.show()

# %%
# Line plot
plt.figure(figsize=(10, 6))
plt.plot(final_data['ais_timestamp'], final_data['max_cm'], marker='o', linestyle='-')
plt.title('Line Plot of max_cm')
plt.xlabel('AIS Timestamp')
plt.ylabel('Max cm')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Bivariate Analysis

# %%
sns.scatterplot(x='speed', y='vessel_length', data=final_data)
plt.title('Speed vs Vessel Length')
plt.show()

# %%
sns.scatterplot(x='max_cm', y='sig_cm', data=final_data)
plt.title('max_cm vs sig_cm')
plt.show()

# %%
sns.scatterplot(x='max_cm', y='turb_cm', data=final_data)
plt.title('max_cm vs turb_cm')
plt.show()

# %%
sns.scatterplot(x='max_cm', y='tp', data=final_data)
plt.title('max_cm vs tp')
plt.show()

# %%
sns.scatterplot(x='sig_cm', y='turb_cm', data=final_data)
plt.title('sig_sm vs turb_cm')
plt.show()

# %%
sns.scatterplot(x='sig_cm', y='tp', data=final_data)
plt.title('sig_cm vs tp')
plt.show()

# %%
sns.scatterplot(x='turb_cm', y='tp', data=final_data)
plt.title('turb_cm vs tp')
plt.show()

# %% [markdown]
# ### Multivariate Analysis

# %%
sns.pairplot(final_data[['speed', 'vessel_length', 'target']])
plt.show()
# Out:
# C:\Users\firoj\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
